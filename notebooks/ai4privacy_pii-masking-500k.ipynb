# %% [markdown]
# ### Upload dataset

# %%
from datasets import load_dataset

ds = load_dataset("ai4privacy/open-pii-masking-500k-ai4privacy")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train/train.jsonl:   0%|          | 0.00/566M [00:00<?, ?B/s]
# data/validation/test.jsonl:   0%|          | 0.00/142M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/464150 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/116077 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset, DatasetDict

print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['source_text', 'masked_text', 'privacy_mask', 'split', 'uid', 'language', 'region', 'script', 'mbert_tokens', 'mbert_token_classes'],
#         num_rows: 464150
#     })
#     validation: Dataset({
#         features: ['source_text', 'masked_text', 'privacy_mask', 'split', 'uid', 'language', 'region', 'script', 'mbert_tokens', 'mbert_token_classes'],
#         num_rows: 116077
#     })
# })

# %%
ds.shape
# Out:
# {'train': (464150, 10), 'validation': (116077, 10)}

# %%
df = ds["train"].to_pandas()
df.head()
# Out:
#                                          source_text  \
# 0  20:10:26 Venanzius Höttermann Revés యొక్క వివా...
# 1  Branislavka: 'Sí, por favor. ¿Cuánta cera de s...
# 2  To-do list for 4th August 1942: meet with Bran...
# 3  Igorche Ramtin Eshekary will need to bring the...
# 4  Shola Kenzi Zimeri used 0111-284596398 to sche...
#
#                                          masked_text  \
# 0  [TIME_1] [GIVENNAME_1] [SURNAME_1] యొక్క వివాహ...
# 1  [GIVENNAME_1]: 'Sí, por favor. ¿Cuánta cera de...
# 2  To-do list for [DATE_1]: meet with [GIVENNAME_...
# 3  [GIVENNAME_1] [SURNAME_1] will need to bring t...
# 4  [GIVENNAME_1] [SURNAME_1] used [TELEPHONENUM_1...
#
#                                         privacy_mask  split      uid language  \
# 0  [{'label': 'TIME', 'start': 0, 'end': 8, 'valu...  train  5387382       te
# 1  [{'label': 'GIVENNAME', 'start': 0, 'end': 11,...  train  5401531       es
# 2  [{'label': 'DATE', 'start': 15, 'end': 30, 'va...  train  5387389       en
# 3  [{'label': 'GIVENNAME', 'start': 0, 'end': 14,...  train  5406386       en
# 4  [{'label': 'GIVENNAME', 'start': 0, 'end': 11,...  train  5402211       en
#
#   region script                                       mbert_tokens  \
# 0     IN   Telu  [20, :, 10, :, 26, Ve, ##nan, ##ziu, ##s, H, #...
# 1     MX   Latn  [Br, ##ani, ##slav, ##ka, :, ', S, ##í, ,, por...
# 2     CA   Latn  [To, -, do, list, for, 4th, August, 1942, :, m...
# 3     GB   Latn  [Igor, ##che, Ram, ##tin, Es, ##he, ##kar, ##y...
# 4     US   Latn  [S, ##hola, Ken, ##zi, Zi, ##meri, used, 011, ...
#
#                                  mbert_token_classes
# 0  [B-TIME, I-TIME, I-TIME, I-TIME, I-TIME, B-GIV...
# 1  [B-GIVENNAME, I-GIVENNAME, I-GIVENNAME, I-GIVE...
# 2  [O, O, O, O, O, B-DATE, I-DATE, I-DATE, O, O, ...
# 3  [B-GIVENNAME, I-GIVENNAME, I-GIVENNAME, I-GIVE...
# 4  [B-GIVENNAME, I-GIVENNAME, I-GIVENNAME, I-GIVE...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464150 entries, 0 to 464149
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   source_text          464150 non-null  object
#  1   masked_text          464150 non-null  object
#  2   privacy_mask         464150 non-null  object
#  3   split                464150 non-null  object
#  4   uid                  464150 non-null  int64
#  5   language             464150 non-null  object
#  6   region               464150 non-null  object
#  7   script               464150 non-null  object
#  8   mbert_tokens         464150 non-null  object
#  9   mbert_token_classes  464150 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 35.4+ MB

# %%
df.head(1).values
# Out:
# array([['20:10:26 Venanzius Höttermann Revés యొక్క వివాహం July/95 నాడు జరిగింది, Tadaలో Faizabad Road వద్ద.',
#         '[TIME_1] [GIVENNAME_1] [SURNAME_1] యొక్క వివాహం [DATE_1] నాడు జరిగింది, [CITY_1]లో [STREET_1] వద్ద.',
#         array([{'label': 'TIME', 'start': 0, 'end': 8, 'value': '20:10:26', 'label_index': 1},
#                {'label': 'GIVENNAME', 'start': 9, 'end': 18, 'value': 'Venanzius', 'label_index': 1},
#                {'label': 'SURNAME', 'start': 19, 'end': 35, 'value': 'Höttermann Revés', 'label_index': 1},
#                {'label': 'DATE', 'start': 49, 'end': 56, 'value': 'July/95', 'label_index': 1},
#                {'label': 'CITY', 'start': 72, 'end': 76, 'value': 'Tada', 'label_index': 1},
#                {'label': 'STREET', 'start': 79, 'end': 92, 'value': 'Faizabad Road', 'label_index': 1}],
#               dtype=object)                                                                                ,
#         'train', 5387382, 'te', 'IN', 'Telu',
#         array(['20', ':', '10', ':', '26', 'Ve', '##nan', '##ziu', '##s', 'H',
#                '##ötter', '##mann', 'Rev', '##és', 'యొక్క', 'వి', '##వ', '##ా',
#                '##హం', 'July', '/', '95', 'న', '##ాడు', 'జరిగింది', ',', 'Tada',
#                '##లో', 'Fa', '##iza', '##bad', 'Road', 'వద్ద', '.'], dtype=object),
#         array(['B-TIME', 'I-TIME', 'I-TIME', 'I-TIME', 'I-TIME', 'B-GIVENNAME',
#                'I-GIVENNAME', 'I-GIVENNAME', 'I-GIVENNAME', 'B-SURNAME',
#                'I-SURNAME', 'I-SURNAME', 'I-SURNAME', 'I-SURNAME', 'O', 'O', 'O',
#                'O', 'O', 'B-DATE', 'I-DATE', 'I-DATE', 'O', 'O', 'O', 'O',
#                'B-CITY', 'O', 'B-STREET', 'I-STREET', 'I-STREET', 'I-STREET', 'O',
#                'O'], dtype=object)                                                ]],
#       dtype=object)

# %%
import pprint as pp 

for i in df.head(1).values, df.columns:
   print(f'{i}\n-----')

# pp.pprint(df.source_text[0])
# print("-----")
# pp.pprint(df.masked_text[0])
# print("-----")
# pp.pprint(df.privacy_mask[0])
# Out:
# [['20:10:26 Venanzius Höttermann Revés యొక్క వివాహం July/95 నాడు జరిగింది, Tadaలో Faizabad Road వద్ద.'
#   '[TIME_1] [GIVENNAME_1] [SURNAME_1] యొక్క వివాహం [DATE_1] నాడు జరిగింది, [CITY_1]లో [STREET_1] వద్ద.'
#   array([{'label': 'TIME', 'start': 0, 'end': 8, 'value': '20:10:26', 'label_index': 1},
#          {'label': 'GIVENNAME', 'start': 9, 'end': 18, 'value': 'Venanzius', 'label_index': 1},
#          {'label': 'SURNAME', 'start': 19, 'end': 35, 'value': 'Höttermann Revés', 'label_index': 1},
#          {'label': 'DATE', 'start': 49, 'end': 56, 'value': 'July/95', 'label_index': 1},
#          {'label': 'CITY', 'start': 72, 'end': 76, 'value': 'Tada', 'label_index': 1},
#          {'label': 'STREET', 'start': 79, 'end': 92, 'value': 'Faizabad Road', 'label_index': 1}],
#         dtype=object)
#   'train' 5387382 'te' 'IN' 'Telu'
#   array(['20', ':', '10', ':', '26', 'Ve', '##nan', '##ziu', '##s', 'H',
#          '##ötter', '##mann', 'Rev', '##és', 'యొక్క', 'వి', '##వ', '##ా',
#          '##హం', 'July', '/', '95', 'న', '##ాడు', 'జరిగింది', ',', 'Tada',
#          '##లో', 'Fa', '##iza', '##bad', 'Road', 'వద్ద', '.'], dtype=object)
#   array(['B-TIME', 'I-TIME', 'I-TIME', 'I-TIME', 'I-TIME', 'B-GIVENNAME',
#          'I-GIVENNAME', 'I-GIVENNAME', 'I-GIVENNAME', 'B-SURNAME',
#          'I-SURNAME', 'I-SURNAME', 'I-SURNAME', 'I-SURNAME', 'O', 'O', 'O',
#          'O', 'O', 'B-DATE', 'I-DATE', 'I-DATE', 'O', 'O', 'O', 'O',
#          'B-CITY', 'O', 'B-STREET', 'I-STREET', 'I-STREET', 'I-STREET', 'O',
#          'O'], dtype=object)                                                ]]
# -----
# Index(['source_text', 'masked_text', 'privacy_mask', 'split', 'uid',
#        'language', 'region', 'script', 'mbert_tokens', 'mbert_token_classes'],
#       dtype='object')
# -----
